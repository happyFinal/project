# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/happyFinal/Kwon/main/%EB%A9%9C%EB%A1%A0_%EA%B0%80%EC%82%AC_%EC%9D%B8%EB%94%94_%EC%9D%B8%EA%B8%B0.csv", index_col="Unnamed: 0")

# %%
df.head(2)
# Out:
#           제목                                                 가사  장르
# 0  해요 (2022)  그녀와 나는요 그땐 참 어렸어요\n많이 사랑했고 때론 많이 다퉜었죠\n지금 생각하면...  인디
# 1      그라데이션  밤은 다시 길고 깊어졌네\n나는 점점 너로 잠 못 들게 돼\n글로 적어내긴 어려운 ...  인디

# %%
import re

for i in range(len(df)):
    df["가사"][i] = re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", " ",df["가사"][i])
    
    
df["가사"]
# Out:
# 0       그녀와 나는요 그땐 참 어렸어요 많이 사랑했고 때론 많이 다퉜었죠 지금 생각하면 모...
# 1       밤은 다시 길고 깊어졌네 나는 점점 너로 잠 못 들게 돼 글로 적어내긴 어려운 이 ...
# 2       알아 내 맘에 조용히 문을 두드리면 눈에 뿌옇게 고여버린 널 흘려보내야 해 기억은 ...
# 3       나는 읽기 쉬운 마음이야 당신도 스윽 훑고 가셔요 달랠 길 없는 외로운 마음 있지 ...
# 4                                   날 좋아하던 그때 수줍게 꽃을 건...
#                               ...
# 8382    언제 내리나 봄비 필요해 포근한 온기 나눠줘 뜨거운 용기 원해 원해 봄비 봄비 봄비...
# 8383                                                  ...
# 8384    툭툭 지나가던 내 걸음이 또또 멀게만 느껴지는 하루에요 난 점점 마음이 겁이 나서 ...
# 8385    회색도시에 사는 외계인들 초록피 사이 빨간게 흘러 달력 칸에 갇힌 체로 태어나서 부...
# 8386    안 돼요 끝나버린 노래를 다시 부를 순 없어요 모두가 그렇게 바라고 있다 해도 더 ...
# Name: 가사, Length: 8387, dtype: object

# %%
df = df.drop_duplicates()

# %%
lyrics = df["가사"].values.tolist()
lyrics[:5]
# Out:
# ['그녀와 나는요 그땐 참 어렸어요 많이 사랑했고 때론 많이 다퉜었죠 지금 생각하면 모두 내 잘못이죠 마지막 그날도 그녀는 울었어 나는 그녈 잡지 못했죠 지금까지도 너무 후회가 돼요 그 후로 누굴 사랑한 적 없어 아직은 그녀와 나는요 언젠가 만날 거죠 변해버린 모습 변해버린 시간 속에 하지만 괜찮아 내 눈엔 아름답던 예전 모습 그대로 일 거예요 그녀도 날 못 잊을 거야 나는 믿어요 그만큼 사랑했죠 그래서 우린 한 번은 만나야만 해요 그녀의 친구라도 이 노랠 듣는다면 그녀에게 전해줘요 내가 아직 사랑한다고 우리가 처음 만난 그 시간 그 자리에 내가 매일 기다린다고 언제라도 그녀도 날 못 잊을 거야 나는 믿어요 그만큼 사랑했죠 그래서 우린 한 번은 만나야만 해요 그녀의 친구라도 이 노랠 듣는다면 그녀에게 전해줘요 내가 아직 사랑한다고 우리가 처음 만난 그 시간 그 자리에 내가 매일 기다린다고 그녀의 친구라도 이 노랠 듣는다면 그녀에게 전해줘요 내가 아직 사랑한다고 우리가 처음 만난 그 시간 그 자리에 내가 매일 기다린다고 내가 매일 기다린다고',
# ...

# %%
# konlpy

# !pip install konlpy --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from konlpy.tag import Kkma

kkma = Kkma()
kkma

# %%
# 명사만 남겨서 워드클라우드 돌리기 

from konlpy.tag import Okt
okt = Okt()

# %%
y = []
for i in range(1000):
    nouns = okt.nouns(lyrics[i])
    y = y + nouns

y[:10]
# Out:
# ['그녀', '그땐', '사랑', '때론', '지금', '생각', '모두', '내', '잘못', '마지막']

# %%
x = []
for i in range(50):
    x = x + okt_clean(lyrics[i])

# %%
x
# Out:
# ['그녀',
#  '나다',
#  '그땐',
#  '차다',
#  '어리다',
#  '많이',
#  '사랑',
#  '하다',
#  '때론',
#  '많이',
#  '다투다',
#  '지금',
#  '생각',
#  '하다',
#  '모두',
#  '내',
#  '잘못',
#  '이',
#  '마지막',
#  '그날',
#  '그녀',
#  '울다',
#  '나',
#  '그녈',
#  '잡지',
#  '못',
#  '하다',
#  '지금',
#  '너무',
#  '후회',
#  '돼다',
#  '그',
#  '후',
#  '누굴',
#  '사랑',
#  '적',
#  '없다',
#  '아직',
#  '은',
#  '그녀',
#  '나다',
#  '언젠가',
#  '만날',
#  '거',
#  '변하다',
#  '버리다',
#  '모습',
#  '변하다',
#  '버리다',
#  '시간',
#  '속',
#  '하지만',
#  '괜찮다',
#  '내',
#  '눈',
#  '아름답다',
#  '예전',
#  '모습',
#  '그대로',
#  '일',
#  '거',
#  '그녀',
#  '날',
#  '못',
#  '잊다',
#  '나',
#  '믿다',
#  '그만큼',
#  '사랑',
#  '하다',
#  '그래서',
#  '우린',
#  '하다',
#  '번은',
#  '만나다',
#  '해',
#  '그녀',
#  '친구',
#  '이',
#  '노랗다',
#  '듣다',
#  '그녀',
#  '전',
#  '해주다',
#  '내',
#  '아직',
#  '사랑',
#  '하다',
#  '우리',
#  '처음',
#  '만난',
#  '그',
#  '시간',
#  '그',
#  '자리',
#  '내',
#  '매일',
#  '기다리다',
#  '언제',
#  '그녀',
#  '날',
#  '못',
#  '잊다',
#  '나',
#  '믿다',
#  '그만큼',
#  '사랑',
#  '하다',
#  '그래서',
#  '우린',
#  '하다',
# ...

# %%
# 일부만

ly_kk = kkma.morphs(lyrics[20])
# 시간 걸림
# Out:
#   0%|          | 0/5603 [00:00<?, ?it/s]

# %%
# 워드클라우드
# 인디


# !apt-get update -qq
# !apt-get install fonts-nanum* -qq  #코랩에서 한글 표기
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
ly_kk

# %%
# lyrics 1000개 중

count={}

for i in y:
    try: count[i] += 1
    except: count[i]=1

print(count)
# Out:
# {'그녀': 75, '그땐': 64, '사랑': 1613, '때론': 22, '지금': 438, '생각': 622, '모두': 231, '내': 2904, '잘못': 22, '마지막': 107, '그날': 114, '나': 2428, '그녈': 1, '잡지': 12, '후회': 102, '그': 1180, '후': 95, '누굴': 13, '적': 96, '은': 43, '만날': 30, '거': 399, '모습': 270, '시간': 611, '속': 482, '눈': 632, '예전': 57, '그대로': 140, '일': 193, '날': 1342, '못': 443, '우린': 390, '번은': 7, '해': 735, '친구': 112, '이': 815, '전': 125, '우리': 1170, '처음': 152, '만난': 44, '자리': 75, '매일': 253, '언제': 99, '밤': 814, '다시': 523, '점점': 73, '너': 3364, '잠': 170, '글': 5, '기분': 135, '아무': 201, '몇': 88, '번': 149, '라지': 1, '옷': 49, '잉크': 4, '낼': 12, '수': 976, '만큼': 69, '색감': 4, '정신': 20, '땐': 115, '수도': 48, '가득': 91, '찬': 26, '마음': 815, '여물': 2, '내일': 149, '말': 1555, '요즘': 64, '노랜': 11, '뭔가': 27, '맘': 543, '안': 459, '네': 1219, '주기': 18, '좀': 234, '나름': 7, '며칠': 6, '연습': 14, '무리': 8, '것': 1026, '더': 779, '하루': 397, '종일': 83, '얼굴': 102, '방': 71, '무지개': 25, '바람': 191, '빗물': 8, '항상': 139, '빛': 187, '테': 74, '전하': 29, '관심': 19, '그림': 35, '그냥': 244, '노래': 246,
# ...

# %%
b
# Out:
#       빈도
# 너   3364
# 내   2904
# 나   2428
# 난   1687
# 사랑  1613
# ..   ...
# 가족    11
# 불면    11
# 피해    11
# 문자    11
# 별일    11
#
# [787 rows x 1 columns]

# %%
#  명사라고 여겨지는 것 추출 및 빈도수 별 시리즈 변환
 
y_freq = pd.Series(count)
a = y_freq.sort_values(ascending=False)
b = pd.DataFrame(a[(1650 > a)&(a > 10)], columns=["빈도"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-c35221137061> in <module>
#       9 w = []
#      10 for i in z:
# ---> 11     if len(z[i]) > 1:
#      12         w.append(z[i])
#      13
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# 2

# %%
word = pd.DataFrame({"단어" : b.index.tolist(),
              "빈도수": b["빈도"]})

wordcloud = WordCloud(
            font_path="NanumGothic",
            width=800,
            height=800
)
text = " ".join(word["단어"])
keyword = wordcloud.generate(text)

array = keyword.to_array()

plt.figure(figsize=(10, 10))
plt.imshow(
    array,
    interpolation="bilinear"
)
plt.axis("off")
plt.show()

# %%
text
# Out:
# '너 내 나 난 사랑 말 날 네 그 우리 널 것 수 그대 마음 이 밤 더 때 해 넌 또 눈 생각 시간 맘 이제 다시 오늘 사람 걸 속 안 왜 게 못 지금 거 하루 우린 기억 니 모든 손 하나 알 꿈 순간 세상 곳 모습 어디 젠 저 건 줄 매일 별 노래 그때 그냥 혼자 좀 모두 위 보고 볼 끝 하늘 곁 뭐 앞 길 아무 둘 일 바람 거리 눈물 빛 여기 조금 다른 서로 정말 추억 잠 가끔 마 꼭 집 두 겨울 뒤 해도 처음 바보 번 내일 전부 이별 당신 자꾸 얘기 늘 그대로 채 항상 사이 기분 멀리 숨 오 소리 사실 살 누구 전 온 꽃 요 그게 듯 위해 비 땐 걱정 그날 척 계절 친구 마지막 위로 미소 계속 후회 목소리 얼굴 옆 품 바다 아마 언제 아침 얼마나 바 애 어제 적 가슴 후 크리스마스 아주 의미 혹시 가득 돈 이름 몇 수가 시작 한번 눈빛 마주 종일 춤 안고 순 뭘 이유 잡고 상처 약속 나나 진짜 입 이야기 자리 봄 그녀 달 날씨 테 향 다음 힘 준비 모 점점 방 도 무슨 어쩌면 가지 거짓말 전화 남아 만큼 새 울 불 머리 누가 여름 술 가장 내겐 표정 몸 잠시 웃음 제발 요즘 그땐 준 뿐 행복 때문 지나 아래 마치 걸음 햇살 라면 남 누군가 슬픔 안녕 발 밤하늘 연락 예전 어른 어 어둠 차라리 문제 피어 무엇 음 대도 필요 시절 이해 이상 두운 향기 절대 이건 기적 저기 벌써 달빛 새벽 물 엄마 년 불빛 아아 말로 고민 옷 놈 홀로 중 감정 수도 간 인사 남자 구름 타고 제일 한참 반복 상상 우릴 영화 문득 밤새 별빛 단 달이 사진 피 음악 범 만난 은 삶 데 진심 어딘가 기대 잠깐 놨다 차 미련 문 아이 보이 건가 오직 표현 내게로 자꾸만 온기 겁 빈 먼저 몰래 곧 일상 노력 이제야 밥 선물 파란색 고백 탓 고 잡 오지 흔적 눈치 란 꿈속 답 인생 심장 입술 대답 소년 도시 아픔 한단 봄날 듯이 기도 선 가요 머릿속 가사 파도 귀 달라 그림 대체 목 그리움 꽤 현실 지난 만 고개 말투 막 일도 욕심 발걸음 어깨 색 간다 취해 멍하니 대신 포기 한숨 
# ...

# %%
plt.rc('font',family='NanumGothic')

# %%
# matplotlib 한글폰트 삽입하기 - 추후 조정

plt.figure(figsize=(20, 12))
pd.Series(count).plot(color="black")
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# EDA로는 이유를 찾아내기 힘듦. 인디 장르를 배제할 타당한 논리 필요.
